# %%
print("hello everyone");
# Out:
# hello everyone

# %%
age =25
price = 19.99
complex_num=3 + 4j

name ="Alice"
message ='python is fun man'

is_student = True
has_job = False

print(f"Name: {name} (Type: {type(name)})")
print(f"Age: {age} (Type: {type(age)})")
print(f"Price: ${price} (Type: {type(price)})")
print(f"Is Student: {is_student} (Type: {type(is_student)})")
# Out:
# Name: Alice (Type: <class 'str'>)
# Age: 25 (Type: <class 'int'>)
# Price: $19.99 (Type: <class 'float'>)
# Is Student: True (Type: <class 'bool'>)

# %%
num_str = "100"
num_int = int(num_str)
print(f'Converting "{num_str}" to integer: {num_int}')

num_float = float(age)
print(f"Converting {age} to float: {num_float}")

age_str = str(age)
print(f"Converting {age} to string: '{age_str}'")

pi = 3.14159
pi_int = int(pi)
print(f"Converting {pi} to integer: {pi_int}")
# Out:
# Converting "100" to integer: 100
# Converting 25 to float: 25.0
# Converting 25 to string: '25'
# Converting 3.14159 to integer: 3

# %%
greeting = "Hello"
name = "Bob"

combined = greeting + " " + name
print(f"Concatenation: {combined}")

laugh = "Ha" * 3
print(f"Repetition: {laugh}")

text = "  Python Programming  "
print(f"Original: '{text}'")
print(f"Strip whitespace: '{text.strip()}'")
print(f"Uppercase: {text.upper()}")
print(f"Lowercase: {text.lower()}")
print(f"Replace: {text.replace('Python', 'Java')}")
print(f"Split: {text.split()}")

name = "Charlie"
score = 95
print(f"Student: {name}, Score: {score}")

word = "Programming"
print(f"Word: {word}")
print(f"First 3 chars: {word[:3]}")
print(f"Last 3 chars: {word[-3:]}")
print(f"Reverse: {word[::-1]}")
# Out:
# Concatenation: Hello Bob
# Repetition: HaHaHa
# Original: '  Python Programming  '
# Strip whitespace: 'Python Programming'
# Uppercase:   PYTHON PROGRAMMING
# Lowercase:   python programming
# Replace:   Java Programming
# Split: ['Python', 'Programming']
# Student: Charlie, Score: 95
# Word: Programming
# First 3 chars: Pro
# Last 3 chars: ing
# Reverse: gnimmargorP

# %%
a = 10
b = 3

print(f"a = {a}, b = {b}")
print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulus: {a} % {b} = {a % b}")
print(f"Exponent: {a} ** {b} = {a ** b}")

print(f"\nComparison Operators:")
print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
print(f"{a} >= {b}: {a >= b}")
print(f"{a} <= {b}: {a <= b}")

print(f"\nLogical Operators:")
x = True
y = False
print(f"x = {x}, y = {y}")
print(f"x and y: {x and y}")
print(f"x or y: {x or y}")
print(f"not x: {not x}")
# Out:
# a = 10, b = 3
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335
# Floor Division: 10 // 3 = 3
# Modulus: 10 % 3 = 1
# Exponent: 10 ** 3 = 1000
#
# Comparison Operators:
# 10 == 3: False
# 10 != 3: True
# 10 > 3: True
# 10 < 3: False
# 10 >= 3: True
# 10 <= 3: False
#
# Logical Operators:
# x = True, y = False
# x and y: False
# x or y: True
# not x: False

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print(f"\nHello {name}! You are {age} years old.")
print(f"In 5 years, you will be {int(age) + 5} years old!")
# Out:
# Enter your name:  ayush katuwal
# Enter your age:  21
# Hello ayush katuwal! You are 21 years old.
# In 5 years, you will be 26 years old!

# %%
temperature = 45;
print(f"Temperature: {temperature}°C")

if temperature > 30:
    print("It's hot outside! ")
elif temperature > 20:
    print("It's warm outside! ")
elif temperature > 10:
    print("It's cool outside! ")
else:
    print("It's cold outside! ")
# Out:
# Temperature: 45°C
# It's hot outside!

# %%
age = 18
has_license = True

if age >= 18:
    if has_license:
        print("You can drive a car! 🚗")
    else:
        print("You're old enough but need a license first!")
else:
    print("You're too young to drive!")
# Out:
# You can drive a car! 🚗

# %%
print("For loop - Counting 1 to 5:")
for i in range(1, 6):
    print(f"Count: {i}")
# Out:
# For loop - Counting 1 to 5:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5

# %%
print("\nFor loop - Iterating through fruits:")
fruits = ["apple", "banana", "orange", "grape"]
for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# For loop - Iterating through fruits:
# I like apple
# I like banana
# I like orange
# I like grape

# %%
print("\nFor loop - Iterating through characters:")
word = "Python"
for letter in word:
    print(f"Letter: {letter}")
# Out:
# For loop - Iterating through characters:
# Letter: P
# Letter: y
# Letter: t
# Letter: h
# Letter: o
# Letter: n

# %%
print("\nWhile loop - Countdown:")
count = 5
while count > 0:
    print(f"Countdown: {count}")
    count -= 1  # Decrease count by 1
print("Blast off! ")
# Out:
# While loop - Countdown:
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Blast off!

# %%
print("\nBreak and Continue Example:")
for num in range(1, 11):
    if num == 5:
        continue  # Skip 5
    if num == 8:
        break     # Stop at 8
    print(f"Number: {num}")
# Out:
# Break and Continue Example:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 6
# Number: 7

# %%
numbers = [1, 2, 3, 4, 5]
mixed = [1, "hello", 3.14, True]
colors = ["red", "green", "blue"]

print(f"Numbers: {numbers}")
print(f"Mixed list: {mixed}")
print(f"Colors: {colors}")
# Out:
# Numbers: [1, 2, 3, 4, 5]
# Mixed list: [1, 'hello', 3.14, True]
# Colors: ['red', 'green', 'blue']

# %%
print(f"\nFirst color: {colors[0]}")
print(f"Last color: {colors[-1]}")
# Out:
# First color: red
# Last color: blue

# %%
colors.append("yellow")  
print(f"After append: {colors}")
# Out:
# After append: ['red', 'green', 'blue', 'yellow']

# %%
colors.insert(1, "orange") 
print(f"After insert: {colors}")
# Out:
# After insert: ['red', 'orange', 'green', 'blue', 'yellow']

# %%
colors.remove("green") 
print(f"After remove: {colors}")
# Out:
# After remove: ['red', 'orange', 'blue', 'yellow']

# %%
print(f"\nFirst 2 colors: {colors[:2]}")
print(f"Last 2 colors: {colors[-2:]}")
# Out:
# First 2 colors: ['red', 'orange']
# Last 2 colors: ['blue', 'yellow']

# %%
squares = [x**2 for x in range(1, 6)]
print(f"\nSquares: {squares}")
# Out:
# Squares: [1, 4, 9, 16, 25]

# %%
squares = [x**2 for x in range(1, 6)]
print(f"\nSquares: {squares}")
# Out:
# Squares: [1, 4, 9, 16, 25]

# %%
person = {
    "name": "John",
    "age": 30,
    "city": "New York",
    "is_student": False
}

print(f"Person dictionary: {person}")
# Out:
# Person dictionary: {'name': 'John', 'age': 30, 'city': 'New York', 'is_student': False}

# %%
print(f"\nName: {person['name']}")
print(f"Age: {person.get('age')}")
# Out:
# Name: John
# Age: 30

# %%
person["age"] = 31
person["job"] = "Engineer"
print(f"\nUpdated person: {person}")
# Out:
# Updated person: {'name': 'John', 'age': 31, 'city': 'New York', 'is_student': False, 'job': 'Engineer'}

# %%
print("\nIterating through dictionary:")
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# Iterating through dictionary:
# name: John
# age: 31
# city: New York
# is_student: False
# job: Engineer

# %%
def greet():
    print("Hello! Welcome to Python!")
def greet_person(name):
    print(f"Hello, {name}!")
def add_numbers(a, b):
    return a + b

def multiply(a, b=2):
    return a * b
greet()
greet_person("Alice")

sum_result = add_numbers(5, 3)
print(f"5 + 3 = {sum_result}")

product = multiply(5)    
print(f"5 * 2 = {product}")

product2 = multiply(5, 4) 
print(f"5 * 4 = {product2}")
# Out:
# Hello! Welcome to Python!
# Hello, Alice!
# 5 + 3 = 8
# 5 * 2 = 10
# 5 * 4 = 20

# %%
def safe_divide(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError:
        return "Cannot divide by zero!"
    except Exception as e:
        return f"An error occurred: {e}"

print(f"10 / 2 = {safe_divide(10, 2)}")
print(f"10 / 0 = {safe_divide(10, 0)}")
# Out:
# 10 / 2 = 5.0
# 10 / 0 = Cannot divide by zero!

# %%
def get_number():
    try:
        num = int(input("Enter a number: "))
        print(f"You entered: {num}")
    except ValueError:
        print("That's not a valid number!")

# %%
def check_even_odd():
    num = int(input("\nEnter a number to check if it's even or odd: "))
    if num % 2 == 0:
        print(f"{num} is EVEN")
    else:
        print(f"{num} is ODD")

# %%
def sum_list(numbers):
    total = 0
    for num in numbers:
        total += num
    return total

my_numbers = [10, 20, 30, 40, 50]
print(f"\nList: {my_numbers}")
print(f"Sum of list: {sum_list(my_numbers)}")
# Out:
# List: [10, 20, 30, 40, 50]
# Sum of list: 150

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

print(f"Factorial of 5: {factorial(5)}")
print(f"Factorial of 7: {factorial(7)}")
# Out:
# Factorial of 5: 120
# Factorial of 7: 5040

# %%
def calculator():
    print("\n--- Simple Calculator ---")
    print("Operations: +, -, *, /")

    num1 = float(input("Enter first number: "))
    op = input("Enter operation (+, -, *, /): ")
    num2 = float(input("Enter second number: "))

    if op == '+':
        result = num1 + num2
    elif op == '-':
        result = num1 - num2
    elif op == '*':
        result = num1 * num2
    elif op == '/':
        if num2 != 0:
            result = num1 / num2
        else:
            result = "Error: Division by zero!"
    else:
        result = "Invalid operation!"

    print(f"Result: {result}")

# %%
name = input("Your name: ")
age = int(input("Your age: "))
# Out:
# Your name:  ayush
# Your age:  21

# %%
birth_year = 2026 - age
print(birth_year)
# Out:
# 2005

# %%
  colors = [c.strip() for c in input("Favorite colors (comma-separated): ").split(",")]
  print(f"Your favorite colors are: {', '.join(colors)}.")
# Out:
# Favorite colors (comma-separated):  rose , rosemary , tulips , lotus
# Your favorite colors are: rose, rosemary, tulips, lotus.

# %%
  print(f"\nHello, {name}! ")
# Out:
# Hello, ayush!
