# %% [markdown]
# <a href="https://colab.research.google.com/github/aayush8644/data-communication1/blob/main/data_communication03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#for loop-iteraring over a range
print('for loop counting 1 to 5:')
for i in range(1,6):
  print(f"count:{i}")
# Out:
# for loop counting 1 to 5:
# count:1
# count:2
# count:3
# count:4
# count:5

# %%
#for loop-iterating over a list
print("\nfor loop-iterating through fruits:")
fruits=["apple","banana","orange","grape"]
for fruit in fruits:
  print(f"i like{fruit}")
# Out:
# for loop-iterating through fruits:
# i likeapple
# i likebanana
# i likeorange
# i likegrape

# %%
#for loop-iterating over string
print("\nfor loop-iterating through character:")
word="python"
for letter in word:
  print(f"letter:{letter}")
# Out:
# for loop-iterating through character:
# letter:p
# letter:y
# letter:t
# letter:h
# letter:o
# letter:n

# %%
# for -while loop
print("\nwhile loop-countdown:")

count = 5

while count > 0:
    print(f"countdown:{count}")
    count -= 1

print("blast off!")
# Out:
# while loop-countdown:
# countdown:5
# countdown:4
# countdown:3
# countdown:2
# countdown:1
# blast off!

# %%
# break and continue example
print("\nbreak and continue example")

for num in range(1, 11):
    if num == 5:
        continue  # Skip 5

    if num == 8:
        break     # Stop loop at 8

    print(f"Number: {num}")
# Out:
# break and continue example
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 6
# Number: 7

# %%
#list and array
print("\n""+ ="*5)
print("LIST")
print("="*50)
# Out:
# + =
# + =
# + =
# + =
# + =
# LIST
# ...

# %%
#creating lists
numbers =[1,2,3,4,5]
mixed=[1,"hello",3.14,True]
colors=["red","green","blue"]

# %%
print(f"Numbers: {numbers}")
print(f"Mixed list: {mixed}")
print(f"Colors: {colors}")
# Out:
# Numbers: [1, 2, 3, 4, 5]
# Mixed list: [1, 'hello', 3.14, True]
# Colors: ['red', 'green', 'blue']

# %%
# Accessing elements
print(f"\nFirst color: {colors[0]}")
print(f"Last color: {colors[-1]}")
# Out:
# First color: red
# Last color: blue

# %%
# List operations
colors.append("yellow")     # Add to end
print(f"After append: {colors}")
# Out:
# After append: ['red', 'green', 'blue', 'yellow']

# %%
colors.insert(1, "orange")  # Insert at position
print(f"After insert: {colors}")
# Out:
# After insert: ['red', 'orange', 'green', 'blue', 'yellow']

# %%
colors.remove("green")       # Remove element
print(f"After remove: {colors}")
# Out:
# After remove: ['red', 'orange', 'blue', 'yellow']

# %%
#slicing list
print(f"\n first two colors: {colors[:2]}")
print(f"last two colors: {colors[-2:]}")
# Out:
#  first two colors: ['red', 'orange']
# last two colors: ['blue', 'yellow']

# %%
#list comprehension
squares=[x**2 for x in range(1,6)]
print(f"\nsquares: {squares}")
# Out:
# squares: [1, 4, 9, 16, 25]

# %%
#dictionaries
print("\n" + "="*50)
print("Dictionaries(key-value paris)")
print("="*50)
# Out:
# ...
# Dictionaries(key-value paris)
# ...

# %%
def multiply(a, b=2):
    return a * b

product = multiply(5)      # Uses default b=2
print(f"5 * 2 = {product}")

# %%
print(f"person dictionary:{person}")
# Out:
# person dictionary:{'name': 'aayush', 'age': 30, 'city': 'newyork', 'is_student': False}

# %%
#Accessing values
print(f"\n name:{person['name']}")
print(f"age:{person.get('age')}")
# Out:
#  name:aayush
# age:30

# %%
#modifying dictionary
person["age"]=31
person["job"]="engineer"
print(f"\nupdate person {person}")
# Out:
# update person {'name': 'aayush', 'age': 31, 'city': 'newyork', 'is_student': False, 'job': 'engineer'}

# %%
# Iterating through dictionary
print("\nIterating through dictionary:")
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# Iterating through dictionary:
# name: aayush
# age: 31
# city: newyork
# is_student: False
# job: engineer

# %%
#simple function
def greet():
  print("HELLO! welcome to python!")

# %%
# Function with parameters
def greet_person(name):
    print(f"Hello, {name}!")

# %%
# Function with return value
def add_numbers(a, b):
    return a + b

# %%
#calling functions
greet()
greet_person("Alice")
# Out:
# HELLO! welcome to python!
# Hello, Alice!

# %%
sum_result = add_numbers(5, 3)
print(f"5 + 3 = {sum_result}")
# Out:
# 5 + 3 = 8

# %%
def multiply(a, b=2):
    return a * b

product = multiply(5)      # Uses default b=2
print(f"5 * 2 = {product}")
# Out:
# 5 * 2 = 10

# %%
product2 = multiply(5,4)
print(f"5*4={product2}")
# Out:
# 5*4=20

# %%
#task1:-create a list of your 5 favourite movies and print each one movies=["inception","titanic","Avatar","stri","daar"]
for movies in movies:
  print(movie)

# %%
movies = ["Inception", "Titanic", "Avatar", "Stree", "Daar"]
for movies in movies:
  print(movies)
# Out:
# Inception
# Titanic
# Avatar
# Stree
# Daar

# %% [markdown]
# task2:-given a list of numbers,find the average grade =[80,90,18,72,76,96]
# average=sum (grades)/len(grades)
# print ("avearge grade :",average)

# %%
# Task 2: Given a list of numbers, find the average

grades = [80, 90, 18, 72, 76, 96]

average = sum(grades) / len(grades)

print("Average grade:", average)
# Out:
# Average grade: 72.0

# %% [markdown]
# task3:-remove duplicate from alist
# num=[1,2,3,4,5]
# unique=list(set(nums))
# print("without duplicate:"unique)

# %%
# Task 3: Remove duplicates from a list

nums = [1, 2, 2, 3, 4, 4, 5]

unique = list(set(nums))

print("Without duplicates:", unique)
# Out:
# Without duplicates: [1, 2, 3, 4, 5]

# %%
task4:-check if a specific item exists in a list
colors=["red","blue","green","yellow"]
