# %%
print("lab3 loops")
print("ayush katuwal")
# Out:
# lab3 loops
# ayush katuwal

# %%
import numpy as np 
import matplotlib as mb

# %%
print("for loop -counting 1 to 5:")
for i in range(1,6):
    print(f"count:{i}")
# Out:
# for loop -counting 1 to 5:
# count:1
# count:2
# count:3
# count:4
# count:5

# %%
print("\nFor loop - Iterating through fruits:")
fruits =["apple","banana","orange","grape"]
for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# For loop - Iterating through fruits:
# I like apple
# I like banana
# I like orange
# I like grape

# %%
print("\nFor loop iterating through the characters")
word ="python"
for letter in word:
    print(f"Letter:{letter}")
# Out:
# For loop iterating through the characters
# Letter:p
# Letter:y
# Letter:t
# Letter:h
# Letter:o
# Letter:n

# %%
print("\n While loop - countdown:")
count = 5 
while count>0:
    print(f"countdown:{count}")
    count -=1
    print("blast off")
print("blast off")
# Out:
#  While loop - countdown:
# countdown:5
# blast off
# countdown:4
# blast off
# countdown:3
# blast off
# countdown:2
# blast off
# countdown:1
# blast off
# blast off

# %%
print("\nBreak and continue Example:")
for num in range(1,11):
        if num ==5:
            continue
        if num ==8:
            break
        print(f"Number:{sum}")
# Out:
# Break and continue Example:
# Number:<built-in function sum>
# Number:<built-in function sum>
# Number:<built-in function sum>
# Number:<built-in function sum>
# Number:<built-in function sum>
# Number:<built-in function sum>

# %%
numbers =[1,2,3,4,5]
mixed = [1,"hello",3.14,True]
colors =["red","green","blue"]
print(f"Numbers:{numbers}")
print(f"mixed list:{mixed}")
print(f"Colors:{colors}")
# Out:
# Numbers:[1, 2, 3, 4, 5]
# mixed list:[1, 'hello', 3.14, True]
# Colors:['red', 'green', 'blue']

# %%
print(f"\nFirst color:{colors[0]}")
print(f"\nLast color:{colors[1]}")
# Out:
# First color:red
#
# Last color:green

# %%
colors.append("yellow")
print(f"After append:{colors}")
# Out:
# After append:['red', 'green', 'blue', 'yellow', 'yellow']

# %%
colors.insert(1,"orange")
print(f"After insert:{colors}")
# Out:
# After insert:['red', 'orange', 'green', 'blue', 'yellow', 'yellow']

# %%
colors.remove("green")
print(f"After remove:{colors}")
# Out:
# After remove:['red', 'orange', 'blue', 'yellow', 'yellow']

# %%
print(f"\nFirst 2 colors:{colors[:2]}")
print(f"Last 2 colors:{colors[-2:]}")
# Out:
# First 2 colors:['red', 'orange']
# Last 2 colors:['yellow', 'yellow']

# %%
squares = [x**2 for x in range(1,6)]
print(f"\nSquares:{squares}")
# Out:
# Squares:[1, 4, 9, 16, 25]

# %%
person = {

"name":"ayush",
"age":21,
"address":"khandbari",
"city":"sankhuwasabha",
"is_student":"True"
}
print(person)
print("his details are",person)
# Out:
# {'name': 'ayush', 'age': 21, 'address': 'khandbari', 'city': 'sankhuwasabha', 'is_student': 'True'}
# his details are {'name': 'ayush', 'age': 21, 'address': 'khandbari', 'city': 'sankhuwasabha', 'is_student': 'True'}

# %%
person["age"]
person["job"] ="Engineer"
person
# Out:
# {'name': 'ayush',
#  'age': 21,
#  'address': 'khandbari',
#  'city': 'sankhuwasabha',
#  'is_student': 'True',
#  'job': 'Engineer'}

# %%
def greet_person(name):
    print(f"hello, {name}!")

def greet_general():
    print("hello! Welcome to python!")

greet_person("ayush")
greet_general()
# Out:
# hello, ayush!
# hello! Welcome to python!

# %%
#class work create a list of your 5 fav movies and print each one 
movies= ["Dhoom2","Conjuring2","Simbha","Ddlj","Sasuralsimarka"]
for movie in movies:
    print("my fav movie is ",movie)
# Out:
# my fav movie is  Dhoom2
# my fav movie is  Conjuring2
# my fav movie is  Simbha
# my fav movie is  Ddlj
# my fav movie is  Sasuralsimarka

# %%
#given the list of  numbers find the average  
grades = [85,90,75,92,88]
average = sum(grades)/len(grades)
print("Average garde is",average
     )
# Out:
# Average garde is 86.0

# %%
#remove duplicates from the set 
nums = [1,2,2,2,3,4,5,6,6,7]
unique = list(set(nums))
print("without duplicates",unique)
# Out:
# without duplicates [1, 2, 3, 4, 5, 6, 7]

# %%
#check if a specific item is on the lust or not 
colors= ["red","blue","greeen","pink"]
search = "t"
if search in colors:
        print(f"{search} is in the list ")
else:
        print(f"{search} is not in the list")
# Out:
# red is in the list
